# %%
# import necessary libraries 
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load and read dataset
Unicorn_data = pd.read_csv(r'C:\Users\olami\Desktop\Python\Unicorn_Companies.csv')
Unicorn_data
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  07/04/2017          Artificial intelligence
# 1          SpaceX     $100B  01/12/2012                            Other
# 2           SHEIN     $100B  03/07/2018  E-commerce & direct-to-consumer
# 3          Stripe      $95B  23/01/2014                          Fintech
# 4          Klarna      $46B  12/12/2011                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  29/06/2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  18/04/2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  06/05/2021                Consumer & retail
# 1072         Zopa       $1B  19/10/2021                          Fintech
# 1073        Zwift       $1B  16/09/2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %% [markdown]
# ### Data Cleaning And Manipulation

# %%
#shape of the data
Unicorn_data.shape
# Out:
# (1074, 10)

# %%
#check the columns
Unicorn_data.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors'],
#       dtype='object')

# %%
#check the data types
Unicorn_data.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country             object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
#info about the data
Unicorn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
#info about the data
Unicorn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
#Check if there are missing values # isna() isnull() 
Unicorn_data.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year Founded         0
# Funding              0
# Select Investors     1
# dtype: int64

# %%
#visualize the missing values
# visualize the missing values
plt.figure(figsize = (10,5))
plt.title('visualizing missing values')
sns.heatmap(Unicorn_data.isnull(), cbar = True, cmap = 'magma_r')
plt.show()

# %% [markdown]
# ### Univariate Analysis of Unicorn Companies

# %%
Unicorn_data.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors'],
#       dtype='object')

# %%
#How many companies are there per continent?
count_country = Unicorn_data['Continent'].value_counts().sort_values(ascending = False)
count_country
# Out:
# North America    589
# Asia             310
# Europe           143
# South America     21
# Oceania            8
# Africa             3
# Name: Continent, dtype: int64

# %%
# Set the figure size
import matplotlib.pyplot as plt

# Assuming you already have the 'count_listing' data from your code
count_country = Unicorn_data['Continent'].value_counts().sort_values(ascending=False)

# Create a horizontal bar chart
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
bars = plt.barh(count_country.index, count_country.values, color='skyblue')

# Adding labels and title
plt.xlabel('Number of Companies')
plt.ylabel('Continent')
plt.title('Number of Companies per Continent')

# Add data labels to the bars
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{bar.get_width():.0f}',
             va='center', ha='left', fontsize=10, color='black')

# Display the chart
plt.show()

# %% [markdown]
# ### Observation
# The North American continent has the highest companies at 589 while Africa has the least with 3

# %% [markdown]
# ### Bivariate Analysis of Unicorn Companies

# %%
#Summary statistics per Continent and Valuation 
# Assuming 'Unicorn_data' is your DataFrame

# Step 1: Clean the 'Valuation' column and convert to numeric
Unicorn_data['Valuation'] = Unicorn_data['Valuation'].str.replace('[\$,B]', '', regex=True).astype(float)

# Step 2: Calculate and round summary statistics
summary_stats = Unicorn_data.groupby('Continent')['Valuation'].describe()
summary_stats = summary_stats.round(0).astype(int)

print(summary_stats)
# Out:
#                count  mean  std  min  25%  50%  75%  max
# Continent
# Africa             3     2    1    1    2    2    2    2
# Asia             310     3   12    1    1    1    3  180
# Europe           143     4    6    1    1    2    3   46
# North America    589     3    7    1    1    2    3  100
# Oceania            8     7   13    1    1    2    4   40
# South America     21     2    2    1    1    2    3    5

# %%
#View distribution of valuation by Continent
plt.figure(figsize = (8,6))
sns.boxplot(x = Unicorn_data['Continent'], y = Unicorn_data['Valuation'], data = Unicorn_data)
plt.title('Distribution of Valuation by Continent')
plt.show()

# %% [markdown]
# ### Observation
# The Asian continent has the highest valuation max which stands at 180 while the african continent had the least valuation which is at 2.

# %%
#Top 5 Industries by Company
top5_val = Unicorn_data.groupby('Industry')['Company'].sum()[:5]
top5_val
# Out:
# Industry
# Artificial Intelligence    UniphoreNotCoCrestaConcertAIShukun TechnologyT...
# Artificial intelligence    BytedanceArgo AIFairePony.aiScale AIGongAutoma...
# Auto & transportation      ZongMu TechnologyBoltNuroOla CabsSVOLTOla Elec...
# Consumer & retail          JUUL LabsGenki ForestWeilong FoodsImpossible F...
# Cybersecurity              SnykTaniumNetskopeLacework1PasswordWizSocureCo...
# Name: Company, dtype: object

# %%
import matplotlib.pyplot as plt

# Assuming 'Unicorn_data' is your DataFrame

# Calculate the top 5 industries by the number of companies
top5_companies = Unicorn_data.groupby('Industry')['Company'].count().nlargest(5)

# Create a bar chart
plt.figure(figsize=(10, 6))
ax = top5_companies.plot(kind='bar', color=plt.cm.Set3.colors)
plt.title('Top 5 Industries by Number of Companies')
plt.xlabel('Industry')
plt.ylabel('Number of Companies')
plt.xticks(rotation=45, ha='right')

# Add data labels on top of each bar
for bar in ax.patches:
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f'{int(bar.get_height()):,}',  # Format the label with commas for thousands
        ha='center',
        va='bottom'
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
# Fintech industries have the most companies with 224 companies

# %% [markdown]
# ### Multivariate Analysis of Unicorn Companies

# %%
#Get the numerical values of the dataset 
num_values = Unicorn_data.describe()

#Display the numerical values
num_values
# Out:
#          Valuation  Year Founded
# count  1074.000000   1074.000000
# mean      3.455307   2012.895717
# std       8.547022      5.698573
# min       1.000000   1919.000000
# 25%       1.000000   2011.000000
# 50%       2.000000   2014.000000
# 75%       3.000000   2016.000000
# max     180.000000   2021.000000

# %%
Unicorn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   float64
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 84.0+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'Unicorn_data' is your DataFrame

# Get the numerical values of the dataset
num_values = Unicorn_data.describe()

# Calculate the correlation matrix
correlation_matrix = Unicorn_data.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()
# Out:
# C:\Users\olami\AppData\Local\Temp\ipykernel_59356\2564666112.py:11: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = Unicorn_data.corr()

# %% [markdown]
# ### Observation
# The red colors show positive correlation while the other shows negative correlation

# %% [markdown]
# ### Recommended Analysis

# %%
#Companies with the biggest return on investment 
import pandas as pd

# Assuming Unicorn_data is your DataFrame

# Define a function to convert strings like "$8B" to numeric values
def convert_to_numeric(value):
    if isinstance(value, str):
        if 'B' in value:
            return float(value.replace('$', '').replace('B', '')) * 1e9
        elif 'M' in value:
            return float(value.replace('$', '').replace('M', '')) * 1e6
        else:
            try:
                return float(value.replace('$', ''))
            except ValueError:
                return None  # Return None for non-convertible values
    return value  # If it's not a string, return the original value (possibly already a float)

# Convert the Valuation and Funding columns to numeric types
Unicorn_data['Valuation'] = Unicorn_data['Valuation'].apply(convert_to_numeric)
Unicorn_data['Funding'] = Unicorn_data['Funding'].apply(convert_to_numeric)

# Filter out rows with non-convertible values (e.g., 'Unknown')
Unicorn_data = Unicorn_data.dropna(subset=['Valuation', 'Funding'])

# Calculate the ROI for each company
Unicorn_data['ROI'] = (Unicorn_data['Valuation'] - Unicorn_data['Funding']) / Unicorn_data['Funding']

# Sort the companies by ROI in descending order
sorted_data = Unicorn_data.sort_values(by='ROI', ascending=False)

# Print the top 5 companies with the highest ROI
top_5_companies = sorted_data.head(5)
print(top_5_companies)
# Out:
#                   Company  Valuation Date Joined  \
# 189  Otto Bock HealthCare        4.0  24/06/2017
# 239                Zapier        4.0  14/01/2021
# 61                 Dunamu        9.0  22/07/2021
# 792             Workhuman        1.0  23/06/2020
# 361                  CFGI        2.0  15/09/2021
#
#                          Industry        City        Country      Continent  \
# 189                        Health  Duderstadt        Germany         Europe
# 239  Internet software & services   Sunnyvale  United States  North America
# 61                        Fintech       Seoul    South Korea           Asia
# 792  Internet software & services      Dublin        Ireland         Europe
# 361                       Fintech      Boston  United States  North America
#
#      Year Founded     Funding  \
# 189          1919         0.0
# 239          2011   1000000.0
# 61           2012  71000000.0
# 792          1999   9000000.0
# 361          2000  19000000.0
#
# ...

# %% [markdown]
# ### Observation
# The top unicorn companies with the biggest return on investment are Otto bock healthcare, Zapier, Dunamu, Workhuman and CFGI

# %%
#Time taken to become a Unicorn 
import pandas as pd

# Sample data (replace with your own dataset)
data = {
    'Company': ['Bytedance', 'SpaceX', 'SHEIN'],
    'Valuation': [180000000000, 100000000000, 100000000000],
    'Funding Date': ['2012', '2002', '2008']
}

Unicorn_data = pd.DataFrame(data)

# Convert 'Funding Date' to datetime objects
Unicorn_data['Funding Date'] = pd.to_datetime(Unicorn_data['Funding Date'])

# Define the unicorn threshold (1 billion)
unicorn_threshold = 1000000000

# Calculate the time taken for each company to become a unicorn
Unicorn_data['Time to Unicorn'] = Unicorn_data.apply(
    lambda row: (row['Funding Date'] - pd.to_datetime('1970-01-01')).days if row['Valuation'] >= unicorn_threshold else None,
    axis=1
)

# Print the DataFrame with time taken to become a unicorn
print(Unicorn_data)
# Out:
#      Company     Valuation Funding Date  Time to Unicorn
# 0  Bytedance  180000000000   2012-01-01            15340
# 1     SpaceX  100000000000   2002-01-01            11688
# 2      SHEIN  100000000000   2008-01-01            13879

# %% [markdown]
# Observation
# It took over 100000 days for the three most valuable companies to become unicorns

# %%
#Countries with the most Unicorns
count_Company = Unicorn_data['Country'].value_counts().sort_values(ascending = False)
count_Company
# Out:
# United States           562
# China                   173
# India                    65
# United Kingdom           43
# Germany                  26
# France                   24
# Israel                   20
# Canada                   19
# Brazil                   16
# Singapore                12
# South Korea              12
# Australia                 8
# Netherlands               6
# Sweden                    6
# Mexico                    6
# Indonesia                 6
# Hong Kong                 6
# Switzerland               5
# Japan                     5
# Ireland                   5
# Finland                   4
# Norway                    4
# Spain                     3
# Belgium                   3
# Turkey                    3
# United Arab Emirates      3
# South Africa              2
# Philippines               2
# Thailand                  2
# Estonia                   2
# Vietnam                   2
# Austria                   2
# Colombia                  2
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have the count_Company variable containing the country counts
count_Company = Unicorn_data['Country'].value_counts().sort_values(ascending=False)

# Extracting data for the bar chart
countries = count_Company.index
unicorn_counts = count_Company.values

# Creating a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(countries, unicorn_counts, color='skyblue')

plt.xlabel('Countries')
plt.ylabel('Number of Unicorns')
plt.title('Unicorn Companies by Country')
plt.xticks(rotation=45, ha='right')

# Adding data labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom', color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
# The United states has the most unicorns at 562 comapnies

# %%
#Cities that are industry hubs 
count_Industry = Unicorn_data['City'].value_counts().sort_values(ascending = False)
count_Industry
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
#                 ...
# Barcelona          1
# Sherman Oaks       1
# Boise              1
# Tsuruoka           1
# Milpitas           1
# Name: City, Length: 256, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming count_Industry contains the city counts
top_cities = count_Industry.head(5)

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(top_cities, labels=top_cities.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Top 5 Cities as Industry Hubs')
plt.show()

# %% [markdown]
# ### Observation
# The following cities are considered industry hubs that there are a lot of unicorn companies operating in such cities San francisco, New York, Beijing, Shanghai and London.

# %%
#Investors that have funded the most Unicorns
import pandas as pd

# Load the dataset
# Replace 'your_dataset.csv' with the actual path to your dataset
Unicorn_data = pd.read_csv(r'C:\Users\olami\Desktop\Python\Unicorn_Companies.csv')

# Split multiple investors into individual rows
investor_rows = Unicorn_data['Select Investors'].str.split(',').explode()

# Remove leading/trailing whitespaces
investor_rows = investor_rows.str.strip()

# Count the number of unicorns each investor has funded
investor_counts = investor_rows.value_counts().sort_values(ascending=False)

# Display the top investors
print(investor_counts)
# Out:
# Accel                        60
# Andreessen Horowitz          53
# Tiger Global Management      53
# Sequoia Capital China        48
# Sequoia Capital              47
#                              ..
# Trifecta Capital Advisors     1
# Leonardo DiCaprio             1
# Promecap                      1
# Songhyun Investment           1
# Causeway Media Partners       1
# Name: Select Investors, Length: 1254, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
# Replace 'your_dataset.csv' with the actual path to your dataset
Unicorn_data = pd.read_csv(r'C:\Users\olami\Desktop\Python\Unicorn_Companies.csv')

# Split multiple investors into individual rows
investor_rows = Unicorn_data['Select Investors'].str.split(',').explode()

# Remove leading/trailing whitespaces
investor_rows = investor_rows.str.strip()

# Count the number of unicorns each investor has funded
investor_counts = investor_rows.value_counts().sort_values(ascending=False)

# Get the top 5 investors
top_investors = investor_counts.head(5)

# Create a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(top_investors.index, top_investors.values, color='skyblue')

# Add data labels on top of bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(bar.get_height()), ha='center', va='bottom')

plt.xlabel('Investors')
plt.ylabel('Number of Unicorns Funded')
plt.title('Top 5 Investors Funding Unicorns')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Observation
# The investors that have funded the most unicorns are Accel with 60 companies, andreessen horowitz with 53, tiger global management with 53, sequoia capital china with 48 and sequoia capital with 47.

# %% [markdown]
# ### Recommendation To Stakeholders
# Stakeholders should grow their geographic area by opening more locations especially in developing continents like Africa this will give them more customers leading to increase sale of products or services which generates more revenue.
